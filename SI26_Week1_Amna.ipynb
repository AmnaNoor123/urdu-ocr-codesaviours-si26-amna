# %% [markdown]
# <a href="https://colab.research.google.com/github/AmnaNoor123/urdu-ocr-codesaviours-si26-amna/blob/main/SI26_Week1_Amna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **What is OCR (Optical Character Recognition)?**
#
# OCR is a technology that helps recognize text, images, drawings, and hand written notes and converts them into digital text that a computer can understand, because when we simply put a picture, the computer doesn't understand what's in it, so OCR extracts text and data from the image.
# Example: Google Lens extracts data from an image.
#
# **Why is Urdu OCR harder than English OCR?**
#
# Urdu OCR is more difficult than English OCR because English is written left to right and its letters are separate, not connected to each other. Urdu, on the other hand, is written right to left, which is already a challenge for the computer to process. Also, Urdu letters are joined together within a word, making it hard for the computer to understand where one letter ends and another begins, or where a word starts and ends.
#
# **What are 2 real-world situations where Urdu OCR would be useful?**
#
# Urdu OCR can be used in apps like Google Lens to scan and extract text from Urdu poetry, making it easy to read, copy, or search the poetry digitally. Another example is scanning official documents like a Nikahnama (marriage certificate), which are usually written in Urdu, so OCR can help convert them into digital text for easy storage and record-keeping.

# %%
import os
import shutil
from google.colab import drive

mountpoint = '/content/drive'

# Ensure the mountpoint is clean before attempting to mount
if os.path.exists(mountpoint):
    if os.path.isdir(mountpoint) and os.listdir(mountpoint):
        print(f"Mountpoint {mountpoint} is not empty. Attempting to remove its contents.")
        try:
            shutil.rmtree(mountpoint) # Remove the directory and its contents
            print(f"Successfully cleared {mountpoint}.")
        except OSError as e:
            print(f"Error clearing mountpoint {mountpoint}: {e}. Trying to remount anyway.")
    elif not os.path.isdir(mountpoint):
        print(f"Mountpoint {mountpoint} exists but is not a directory. Removing it.")
        try:
            os.remove(mountpoint)
            print(f"Successfully removed non-directory {mountpoint}.")
        except OSError as e:
            print(f"Error removing non-directory mountpoint {mountpoint}: {e}. Trying to remount anyway.")

# Recreate the directory if it was removed or didn't exist, to ensure it's a directory for mounting
if not os.path.exists(mountpoint):
    os.makedirs(mountpoint, exist_ok=True)

drive.mount(mountpoint, force_remount=True)
# Out:
# Mountpoint /content/drive is not empty. Attempting to remove its contents.
# Error clearing mountpoint /content/drive: [Errno 125] Operation canceled: '/content/drive/.Encrypted/MyDrive'. Trying to remount anyway.
# Mounted at /content/drive

# %%
import os

folders = [
    'data/raw/Newspaper',
    'data/raw/Books',
    'data/raw/Sign boards',
    'data/raw/Other',
    'data/raw/Synthetic raw images',
    'data/raw/Handwritten'
]
for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f'Created: {folder}')
print('Folder structure ready!')
# Out:
# Created: data/raw/Newspaper
# Created: data/raw/Books
# Created: data/raw/Sign boards
# Created: data/raw/Other
# Created: data/raw/Synthetic raw images
# Created: data/raw/Handwritten
# Folder structure ready!

# %% [markdown]
# **Synthetic Images — Nastaliq Font (20 images)**

# %%
# !pip install Pillow
# !wget -O NotoNastaliqUrdu-Regular.ttf https://github.com/googlefonts/noto-fonts/raw/main/hinted/ttf/NotoNastaliqUrdu/NotoNastaliqUrdu-Regular.ttf

from PIL import Image, ImageDraw, ImageFont
import os

urdu_texts_nastaliq = [
    "پاکستان زندہ باد",
    "آج کا موسم خوشگوار ہے",
    "تعلیم ہر انسان کا حق ہے",
    "کراچی پاکستان کا سب سے بڑا شہر ہے",
    "محنت کامیابی کی کنجی ہے",
    "کتاب علم کا خزانہ ہے",
    "وقت کی قدر کرنی چاہیے",
    "صحت ہزار نعمت ہے",
    "پانی زندگی کے لیے ضروری ہے",
    "سچائی ہمیشہ کامیاب ہوتی ہے",
    "لاہور ایک تاریخی شہر ہے",
    "بچوں کو اچھی تربیت دینی چاہیے",
    "دوستی ایک قیمتی رشتہ ہے",
    "صبر کا پھل میٹھا ہوتا ہے",
    "اردو ایک خوبصورت زبان ہے",
    "درخت لگانا ضروری ہے",
    "والدین کی عزت کرنی چاہیے",
    "علم حاصل کرنے کی کوئی عمر نہیں ہوتی",
    "ایمانداری بہترین پالیسی ہے",
    "پاکستان کا موسم بہت متنوع ہے"
]

os.makedirs('data/raw/Synthetic raw images', exist_ok=True)
nastaliq_font = ImageFont.truetype('NotoNastaliqUrdu-Regular.ttf', 28)

for i, text in enumerate(urdu_texts_nastaliq):
    img = Image.new('RGB', (400, 80), color='white')
    draw = ImageDraw.Draw(img)
    draw.text((10, 20), text, fill='black', font=nastaliq_font, direction='rtl')
    img.save(f'data/raw/Synthetic raw images/urdu_{i+1}.png')
    print(f'Generated: urdu_{i+1}.png -- {text}')

print('Done! 20 Nastaliq synthetic images ready')
# Out:
# ...
# --2026-07-29 20:53:57--  https://github.com/googlefonts/noto-fonts/raw/main/hinted/ttf/NotoNastaliqUrdu/NotoNastaliqUrdu-Regular.ttf
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/notofonts/noto-fonts/raw/main/hinted/ttf/NotoNastaliqUrdu/NotoNastaliqUrdu-Regular.ttf [following]
# --2026-07-29 20:53:57--  https://github.com/notofonts/noto-fonts/raw/main/hinted/ttf/NotoNastaliqUrdu/NotoNastaliqUrdu-Regular.ttf
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/notofonts/noto-fonts/main/hinted/ttf/NotoNastaliqUrdu/NotoNastaliqUrdu-Regular.ttf [following]
# --2026-07-29 20:53:57--  https://raw.githubusercontent.com/notofonts/noto-fonts/main/hinted/ttf/NotoNastaliqUrdu/NotoNastaliqUrdu-Regular.ttf
# ...

# %% [markdown]
# **Synthetic Images — Naskh Font (21 images, for variety)**

# %%
# !wget -O NotoNaskhArabic-Regular.ttf https://raw.githubusercontent.com/notofonts/notofonts.github.io/noto-monthly-release-2025.12.01/fonts/NotoNaskhArabic/hinted/ttf/NotoNaskhArabic-Regular.ttf

from PIL import Image, ImageDraw, ImageFont
import os

urdu_texts_naskh = [
    "دریا کنارے خوبصورت منظر تھا",
    "بچے پارک میں کھیل رہے ہیں",
    "استاد نے سبق اچھی طرح سمجھایا",
    "بازار میں بہت رش تھا",
    "میں نے کتاب پڑھ کر رکھ دی",
    "چاند رات کو بہت روشن تھا",
    "کسان کھیت میں کام کر رہا تھا",
    "دوست نے مجھے تحفہ دیا",
    "بارش کے بعد ہوا خوشگوار ہو گئی",
    "ماں نے کھانا بنایا",
    "طالب علم امتحان کی تیاری کر رہا ہے",
    "پرندے صبح سویرے چہچہاتے ہیں",
    "شہر کی سڑکیں کشادہ ہیں",
    "پہاڑوں پر برف پڑی ہوئی تھی",
    "دکاندار نے سامان تول کر دیا",
    "علم انسان کی سب سے بڑی طاقت ہے",
    "محنت کبھی رائیگاں نہیں جاتی",
    "صحت مند جسم میں صحت مند دماغ ہوتا ہے",
    "پاکستان کے شمالی علاقے بہت خوبصورت ہیں",
    "کتاب انسان کی بہترین دوست ہے",
    "زندگی میں صبر بہت ضروری ہے"
]

os.makedirs('data/raw/Synthetic raw images', exist_ok=True)
naskh_font = ImageFont.truetype('NotoNaskhArabic-Regular.ttf', 28)

for i, text in enumerate(urdu_texts_naskh):
    img = Image.new('RGB', (400, 80), color='white')
    draw = ImageDraw.Draw(img)
    draw.text((10, 20), text, fill='black', font=naskh_font, direction='rtl')
    img.save(f'data/raw/Synthetic raw images/urdu_naskh_{i+1}.png')
    print(f'Generated: urdu_naskh_{i+1}.png -- {text}')

print('Done! 21 Naskh synthetic images ready')
# Out:
# --2026-07-29 20:54:08--  https://raw.githubusercontent.com/notofonts/notofonts.github.io/noto-monthly-release-2025.12.01/fonts/NotoNaskhArabic/hinted/ttf/NotoNaskhArabic-Regular.ttf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 246852 (241K) [application/octet-stream]
# Saving to: ‘NotoNaskhArabic-Regular.ttf’
#
# NotoNaskhArabic-Reg 100%[===================>] 241.07K  --.-KB/s    in 0.02s
#
# 2026-07-29 20:54:09 (9.57 MB/s) - ‘NotoNaskhArabic-Regular.ttf’ saved [246852/246852]
#
# Generated: urdu_naskh_1.png -- دریا کنارے خوبصورت منظر تھا
# Generated: urdu_naskh_2.png -- بچے پارک میں کھیل رہے ہیں
# Generated: urdu_naskh_3.png -- استاد نے سبق اچھی طرح سمجھایا
# Generated: urdu_naskh_4.png -- بازار میں بہت رش تھا
# ...

# %% [markdown]
# **Other Categories — Newspaper, Signboards, Books, Other, Handwritten**
#
# Images for these folders were collected manually (screenshots, WhatsApp images, phone photos of handwriting) and from a labeled real-newspaper dataset, then placed directly into:
# - data/raw/Newspaper/
# - data/raw/Sign boards/
# - data/raw/Books/
# - data/raw/Other/
# - data/raw/Handwritten/
#
# Make sure all these images are uploaded/placed in their folders before running the labels cell below.

# %%
import csv

# Synthetic images - Nastaliq font (20)
synthetic_labels = [
    {'image': 'data/raw/Synthetic raw images/urdu_1.png', 'text': 'پاکستان زندہ باد'},
    {'image': 'data/raw/Synthetic raw images/urdu_2.png', 'text': 'آج کا موسم خوشگوار ہے'},
    {'image': 'data/raw/Synthetic raw images/urdu_3.png', 'text': 'تعلیم ہر انسان کا حق ہے'},
    {'image': 'data/raw/Synthetic raw images/urdu_4.png', 'text': 'کراچی پاکستان کا سب سے بڑا شہر ہے'},
    {'image': 'data/raw/Synthetic raw images/urdu_5.png', 'text': 'محنت کامیابی کی کنجی ہے'},
    {'image': 'data/raw/Synthetic raw images/urdu_6.png', 'text': 'کتاب علم کا خزانہ ہے'},
    {'image': 'data/raw/Synthetic raw images/urdu_7.png', 'text': 'وقت کی قدر کرنی چاہیے'},
    {'image': 'data/raw/Synthetic raw images/urdu_8.png', 'text': 'صحت ہزار نعمت ہے'},
    {'image': 'data/raw/Synthetic raw images/urdu_9.png', 'text': 'پانی زندگی کے لیے ضروری ہے'},
    {'image': 'data/raw/Synthetic raw images/urdu_10.png', 'text': 'سچائی ہمیشہ کامیاب ہوتی ہے'},
    {'image': 'data/raw/Synthetic raw images/urdu_11.png', 'text': 'لاہور ایک تاریخی شہر ہے'},
    {'image': 'data/raw/Synthetic raw images/urdu_12.png', 'text': 'بچوں کو اچھی تربیت دینی چاہیے'},
    {'image': 'data/raw/Synthetic raw images/urdu_13.png', 'text': 'دوستی ایک قیمتی رشتہ ہے'},
    {'image': 'data/raw/Synthetic raw images/urdu_14.png', 'text': 'صبر کا پھل میٹھا ہوتا ہے'},
    {'image': 'data/raw/Synthetic raw images/urdu_15.png', 'text': 'اردو ایک خوبصورت زبان ہے'},
    {'image': 'data/raw/Synthetic raw images/urdu_16.png', 'text': 'درخت لگانا ضروری ہے'},
    {'image': 'data/raw/Synthetic raw images/urdu_17.png', 'text': 'والدین کی عزت کرنی چاہیے'},
    {'image': 'data/raw/Synthetic raw images/urdu_18.png', 'text': 'علم حاصل کرنے کی کوئی عمر نہیں ہوتی'},
    {'image': 'data/raw/Synthetic raw images/urdu_19.png', 'text': 'ایمانداری بہترین پالیسی ہے'},
    {'image': 'data/raw/Synthetic raw images/urdu_20.png', 'text': 'پاکستان کا موسم بہت متنوع ہے'},
]

# Synthetic images - Naskh font (21)
synthetic_naskh_labels = [
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_1.png', 'text': 'دریا کنارے خوبصورت منظر تھا'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_2.png', 'text': 'بچے پارک میں کھیل رہے ہیں'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_3.png', 'text': 'استاد نے سبق اچھی طرح سمجھایا'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_4.png', 'text': 'بازار میں بہت رش تھا'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_5.png', 'text': 'میں نے کتاب پڑھ کر رکھ دی'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_6.png', 'text': 'چاند رات کو بہت روشن تھا'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_7.png', 'text': 'کسان کھیت میں کام کر رہا تھا'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_8.png', 'text': 'دوست نے مجھے تحفہ دیا'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_9.png', 'text': 'بارش کے بعد ہوا خوشگوار ہو گئی'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_10.png', 'text': 'ماں نے کھانا بنایا'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_11.png', 'text': 'طالب علم امتحان کی تیاری کر رہا ہے'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_12.png', 'text': 'پرندے صبح سویرے چہچہاتے ہیں'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_13.png', 'text': 'شہر کی سڑکیں کشادہ ہیں'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_14.png', 'text': 'پہاڑوں پر برف پڑی ہوئی تھی'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_15.png', 'text': 'دکاندار نے سامان تول کر دیا'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_16.png', 'text': 'علم انسان کی سب سے بڑی طاقت ہے'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_17.png', 'text': 'محنت کبھی رائیگاں نہیں جاتی'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_18.png', 'text': 'صحت مند جسم میں صحت مند دماغ ہوتا ہے'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_19.png', 'text': 'پاکستان کے شمالی علاقے بہت خوبصورت ہیں'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_20.png', 'text': 'کتاب انسان کی بہترین دوست ہے'},
    {'image': 'data/raw/Synthetic raw images/urdu_naskh_21.png', 'text': 'زندگی میں صبر بہت ضروری ہے'},
]

# Handwritten images (15)
handwritten_labels = [
    {'image': 'data/raw/Handwritten/handwritten_1.jpeg', 'text': 'میرے کپڑے استری کردو'},
    {'image': 'data/raw/Handwritten/handwritten_2.jpeg', 'text': 'مجھے کھیلنا پسند ہے'},
    {'image': 'data/raw/Handwritten/handwritten_3.jpeg', 'text': 'ٹماٹر، پیاز'},
    {'image': 'data/raw/Handwritten/handwritten_4.jpeg', 'text': 'میں کھانا گرم کرکے آتی ہوں'},
    {'image': 'data/raw/Handwritten/handwritten_5.jpeg', 'text': 'میں ایک مجبور لڑکی ہوں'},
    {'image': 'data/raw/Handwritten/handwritten_6.jpeg', 'text': 'میں کام کرنا جانتی ہوں'},
    {'image': 'data/raw/Handwritten/handwritten_7.jpeg', 'text': 'میں ایک سندر لڑکی ہوں'},
    {'image': 'data/raw/Handwritten/handwritten_8.jpeg', 'text': 'سیب کا ڈالیہ دے دو'},
    {'image': 'data/raw/Handwritten/handwritten_9.jpeg', 'text': 'مجھے کھانا پکانے کا شوق ہے'},
    {'image': 'data/raw/Handwritten/handwritten_10.jpeg', 'text': 'میں بہت سمجھدار لڑکی ہوں'},
    {'image': 'data/raw/Handwritten/handwritten_11.jpeg', 'text': 'کھانا'},
    {'image': 'data/raw/Handwritten/handwritten_12.jpeg', 'text': 'آلو'},
    {'image': 'data/raw/Handwritten/handwritten_13.jpeg', 'text': 'میں ایک خوبصورت لڑکی ہوں'},
    {'image': 'data/raw/Handwritten/handwritten_14.jpeg', 'text': 'میرا نام آمنہ ہے'},
    {'image': 'data/raw/Handwritten/handwritten_15.jpeg', 'text': 'میں گانا گانا جانتی ہوں'},
]

newspaper_labels = [
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_183748.png', 'text': 'خواہش!'},
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_184136.png', 'text': 'تازہ ترین خبروں، تجزیے اور تبصرے کے لیے یہاں کلک کیجیے'},
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_184154.png', 'text': 'ٹی ایل پی سربراہ سعد رضوی اور ان کے بھائی کی گمشدگی کا معمہ برقرار'},
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_184212.png', 'text': 'ایران نے مذاکرات کے لیے رابطہ کیا ہے مگر اس سے پہلے کارروائی بھی ہوسکتی ہے، ٹرمپ'},
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_184222.png', 'text': 'ملک میں شدید سردی کی افواہوں کی تردید'},
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_184703.png', 'text': 'ہر دفعہ پتھر کو لوگ دل سمجھ لیتے ہیں، عمریں بیت جاتی ہیں دل کو دل بنانے میں'},
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_184759.png', 'text': 'کچھ تعلقات ختم کرنے ہی کو پڑتے ہیں'},
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_184814.png', 'text': 'اس وقت پاکستان بہت سے ملکی اور بین الاقوامی مسائل میں گھرا ہوا ہے'},
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_184838.png', 'text': 'علم بڑی دولت ہے، ہم اسے حاصل کرنے کے لیے صرف محنت کرتے ہیں'},
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_184851.png', 'text': 'پاکستان بنیادی طور پر ایک زرعی ملک ہے'},
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_184947.png', 'text': 'وقت کی پابندی'},
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_185017.png', 'text': 'ہر لذت کی انتہا بیزاری ہے'},
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_185028.png', 'text': 'اختلاف کے باوجود احترام سے پیش آنا کمزوری نہیں'},
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_185046.png', 'text': 'راز، تم مرد ہو کر عورت کو بدنام کرتے ہو'},
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_185057.png', 'text': 'انسان مکان بدلتا ہے رشتے بدلتا ہے'},
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_185144.png', 'text': 'غلطیاں بھی ہوں گی، غلط بھی سمجھا جانے گا یہ زندگی ہے'},
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_185221.png', 'text': 'درخت، مشکل، یونٹ، جب تک، معمول'},
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_185235.png', 'text': 'ہجر'},
    {'image': 'data/raw/Newspaper/Screenshot_2026-07-21_185309.png', 'text': 'چاہت'},
    {'image': 'data/raw/Newspaper/WhatsApp_Image_2026-07-21_at_18_34_40.jpeg', 'text': 'بارش کی تباہ کاریاں، 16 افراد پانی میں بہہ گئے'},
    {'image': 'data/raw/Newspaper/0.png', 'text': 'پشاور،بنوں (نمائندہ جنگ،اے ایف پی) بنوں میں اقوام میراخیل اور'},
    {'image': 'data/raw/Newspaper/1.png', 'text': 'اسکے ساتھ ملحقہ علاقے کے عوام نے بجلی و گیس'},
    {'image': 'data/raw/Newspaper/9.png', 'text': 'میں اقوام میراخیل اور اسکے ساتھ ملحقہ علاقے کے عوام'},
    {'image': 'data/raw/Newspaper/10.png', 'text': 'نے بجلی وگیس کی لوڈشیڈنگ کیخلاف مظاہرہ کیا۔ مظاہرین نے'},
    {'image': 'data/raw/Newspaper/17.png', 'text': 'ملانے والی مرکزی شاہراہ پر کرفیو نافذ کردیا گیا ہے۔بنوں'},
    {'image': 'data/raw/Newspaper/100.png', 'text': 'نہیں آ یا۔ آخریہ کونسا مذہب ہے؟کیا اسلام کے نام'},
    {'image': 'data/raw/Newspaper/1000.png', 'text': 'ضرور ہے۔ انہوں نے کہا کہ میرا احمدیوں سے کوئی'},
    {'image': 'data/raw/Newspaper/1001.png', 'text': 'تعلق نہیں، انہوں نے کہا کہ پولیس کو اپنی کارکردگی'},
    {'image': 'data/raw/Newspaper/6651.png', 'text': 'میں کُل جماعتی کشمیر رابطہ کمیٹی کے زیر اہتمام ہونے'},
    {'image': 'data/raw/Newspaper/6652.png', 'text': 'والے کشمیر سیمینار کے ساتھ بھر پو تعاون کا فیصلہ'},
    {'image': 'data/raw/Newspaper/6653.png', 'text': 'کیا گیا۔ چوہدری ظفر اقبال نے کہا لبریشن لیگ کے'},
    {'image': 'data/raw/Newspaper/6654.png', 'text': 'سربراہ کے ایچ خورشید مرحوم نے آج سے نصف صدی'},
    {'image': 'data/raw/Newspaper/6655.png', 'text': 'پہلے کشمیریوں اور پاکستانیوں کو جو تجاویز دیں وہ اگر'},
    {'image': 'data/raw/Newspaper/6656.png', 'text': 'اپنائی جاتیں تو یہ مسئلہ کب کا حل ہوجاتا۔ محمد'},
    {'image': 'data/raw/Newspaper/6657.png', 'text': 'ایاز نے خطاب کرتے ہوئے کہا کہ آزاد کشمیر میں'},
    {'image': 'data/raw/Newspaper/6658.png', 'text': 'لبریشن لیگ واحد جماعت ہے جس نے اصول کی سیاست'},
    {'image': 'data/raw/Newspaper/6659.png', 'text': 'کی ہے، مقبوضہ کشمیر میں ہونے والے مظالم کو دنیا'},
    {'image': 'data/raw/Newspaper/8816.png', 'text': 'حد سے بڑھیں تو پاکستان میں پہلی مرتبہ 1953ء میں'},
    {'image': 'data/raw/Newspaper/8817.png', 'text': 'قادیانیت کے خلاف تحریک چلی، علماء اہلسنّت نے مسئلہ ختم'},
    {'image': 'data/raw/Newspaper/8818.png', 'text': 'نبوت اور فتنہ قادیانیت کو طشت ازبام کیا جبکہ دوسری'},
    {'image': 'data/raw/Newspaper/8819.png', 'text': 'دفعہ 1974ء میں قادیانیت کے خلاف تحریک چلی اور کامیابی'},
    {'image': 'data/raw/Newspaper/8820.png', 'text': 'سے ہمکنار ہوئی، انہوں نے کہا کہ غیر مسلم اقلیت'},
    {'image': 'data/raw/Newspaper/10000.png', 'text': 'ڈالر کی قدر میں اضافہ ہوگیا تاہم یورپین ممالک کی'},
    {'image': 'data/raw/Newspaper/10001.png', 'text': 'اہم کرنسیوں بشمول یورو اور برطانوی پاؤنڈ کی قدر میں'},
    {'image': 'data/raw/Newspaper/10002.png', 'text': 'کمی ریکارڈ کی گئی۔ منگل کو امریکی ڈالر کی قیمت'},
    {'image': 'data/raw/Newspaper/10003.png', 'text': 'فروخت اور قیمت خرید میں بالترتیب 21 پیسے اور 20'},
    {'image': 'data/raw/Newspaper/10004.png', 'text': 'پیسے کی تیزی رہی، تاہم یورو کی قیمت فروخت میں'},
    {'image': 'data/raw/Newspaper/10005.png', 'text': '50 پیسے اور قیمت خرید میں 49 پیسے کی کمی'},
    {'image': 'data/raw/Newspaper/10006.png', 'text': 'ریکارڈ کی گئی۔ اسی طرح برطانوی پاؤنڈ کی قدر میں'},
    {'image': 'data/raw/Newspaper/10007.png', 'text': 'بھی 45 پیسے کی مندی رہی۔ نیشنل بینک آف پاکستان'},
    {'image': 'data/raw/Newspaper/10008.png', 'text': 'سے جاری کردہ اعداد و شمار کے مطابق امریکی ڈالر'},
    {'image': 'data/raw/Newspaper/10009.png', 'text': 'اپنی گزشتہ کاروباری روز کی قیمت فروخت 88.17 روپے سے'},
]

# Signboards images (20)
signboards_labels = [
    {'image': 'data/raw/Sign boards/Screenshot_2026-07-21_185327.png', 'text': 'ارمان'},
    {'image': 'data/raw/Sign boards/WhatsApp_Image_2026-07-21_at_18_56_04.jpeg', 'text': 'سرٹیفکیٹ کے حصول کے لیے درخواست'},
    {'image': 'data/raw/Sign boards/WhatsApp_Image_2026-07-21_at_18_56_14.jpeg', 'text': 'وہاں ریاض مسلسل سے کام چلتا ہے، یہاں گلے کے سہارے کلام چلتا ہے'},
    {'image': 'data/raw/Sign boards/WhatsApp_Image_2026-07-21_at_18_56_40.jpeg', 'text': 'کرکٹ کے کھیل کا موازنہ مشاعرے کے ساتھ کیا گیا ہے'},
    {'image': 'data/raw/Sign boards/WhatsApp_Image_2026-07-21_at_18_57_07.jpeg', 'text': 'کرکٹ اور مشاعرہ (نظم) از دلاور فگار'},
    {'image': 'data/raw/Sign boards/WhatsApp_Image_2026-07-21_at_18_58_13.jpeg', 'text': 'شیطان آپ کو ہر وقت غمگین کیوں کرتا ہے'},
    {'image': 'data/raw/Sign boards/WhatsApp_Image_2026-07-21_at_18_58_25.jpeg', 'text': 'تیسرے حرف کے مطابق: اگر تیسرے حرف پر فتحہ یا کسرہ ہو تو ہمزہ وصلی کو کسرہ دیں گے'},
    {'image': 'data/raw/Sign boards/WhatsApp_Image_2026-07-21_at_18_58_37.jpeg', 'text': 'تیسرے حرف کے مطابق: اگر تیسرے حرف پر ضمہ ہو تو ہمزہ وصلی کو ضمہ دیں گے'},
    {'image': 'data/raw/Sign boards/WhatsApp_Image_2026-07-21_at_19_00_40.jpeg', 'text': 'میں سالار سکندر سے بات کرنا چاہتی ہوں، آپ امامہ ہاشم ہیں؟'},
    {'image': 'data/raw/Sign boards/WhatsApp_Image_2026-07-21_at_19_01_02.jpeg', 'text': 'جو مری ہے وہ میری بیوی تھی اور مجھے بہت پیاری تھی'},
    {'image': 'data/raw/Sign boards/WhatsApp_Image_2026-07-21_at_19_01_14.jpeg', 'text': 'اعمال کے نتائج ہوتے ہیں اور وہ بھگتنے بھی پڑتے ہیں'},
    {'image': 'data/raw/Sign boards/ء_998.png', 'text': 'ء'},
    {'image': 'data/raw/Sign boards/ء_999.png', 'text': 'ء'},
    {'image': 'data/raw/Sign boards/ا_973.png', 'text': 'ا'},
    {'image': 'data/raw/Sign boards/ا_974.png', 'text': 'ا'},
    {'image': 'data/raw/Sign boards/آ_993.png', 'text': 'آ'},
    {'image': 'data/raw/Sign boards/آ_994.png', 'text': 'آ'},
    {'image': 'data/raw/Sign boards/ب_996.png', 'text': 'ب'},
    {'image': 'data/raw/Sign boards/ب_997.png', 'text': 'ب'},
    {'image': 'data/raw/Sign boards/پ_94.png', 'text': 'پ'},
]

# Books images (40)
books_labels = [
    {'image': 'data/raw/Books/ۃ_96.png', 'text': 'ۃ'},
    {'image': 'data/raw/Books/ۃ_97.png', 'text': 'ۃ'},
    {'image': 'data/raw/Books/ت_95.png', 'text': 'ت'},
    {'image': 'data/raw/Books/ت_96.png', 'text': 'ت'},
    {'image': 'data/raw/Books/ٹ_98.png', 'text': 'ٹ'},
    {'image': 'data/raw/Books/ٹ_99.png', 'text': 'ٹ'},
    {'image': 'data/raw/Books/ث_983.png', 'text': 'ث'},
    {'image': 'data/raw/Books/ث_984.png', 'text': 'ث'},
    {'image': 'data/raw/Books/ج_97.png', 'text': 'ج'},
    {'image': 'data/raw/Books/ج_98.png', 'text': 'ج'},
    {'image': 'data/raw/Books/چ_95.png', 'text': 'چ'},
    {'image': 'data/raw/Books/چ_96.png', 'text': 'چ'},
    {'image': 'data/raw/Books/ح_970.png', 'text': 'ح'},
    {'image': 'data/raw/Books/ح_971.png', 'text': 'ح'},
    {'image': 'data/raw/Books/خ_949.png', 'text': 'خ'},
    {'image': 'data/raw/Books/خ_950.png', 'text': 'خ'},
    {'image': 'data/raw/Books/د_95.png', 'text': 'د'},
    {'image': 'data/raw/Books/د_96.png', 'text': 'د'},
    {'image': 'data/raw/Books/ڈ_95.png', 'text': 'ڈ'},
    {'image': 'data/raw/Books/ڈ_96.png', 'text': 'ڈ'},
    {'image': 'data/raw/Books/ذ_98.png', 'text': 'ذ'},
    {'image': 'data/raw/Books/ذ_99.png', 'text': 'ذ'},
    {'image': 'data/raw/Books/ر_980.png', 'text': 'ر'},
    {'image': 'data/raw/Books/ر_981.png', 'text': 'ر'},
    {'image': 'data/raw/Books/ڑ_93.png', 'text': 'ڑ'},
    {'image': 'data/raw/Books/ڑ_94.png', 'text': 'ڑ'},
    {'image': 'data/raw/Books/ز_99.png', 'text': 'ز'},
    {'image': 'data/raw/Books/ز_970.png', 'text': 'ز'},
    {'image': 'data/raw/Books/ژ_98.png', 'text': 'ژ'},
    {'image': 'data/raw/Books/ژ_99.png', 'text': 'ژ'},
    {'image': 'data/raw/Books/س_97.png', 'text': 'س'},
    {'image': 'data/raw/Books/س_98.png', 'text': 'س'},
    {'image': 'data/raw/Books/ش_983.png', 'text': 'ش'},
    {'image': 'data/raw/Books/ش_984.png', 'text': 'ش'},
    {'image': 'data/raw/Books/ص_98.png', 'text': 'ص'},
    {'image': 'data/raw/Books/ص_99.png', 'text': 'ص'},
    {'image': 'data/raw/Books/ض_979.png', 'text': 'ض'},
    {'image': 'data/raw/Books/ض_980.png', 'text': 'ض'},
    {'image': 'data/raw/Books/ط_973.png', 'text': 'ط'},
    {'image': 'data/raw/Books/ط_974.png', 'text': 'ط'},
]

# Other images (32)
other_labels = [
    {'image': 'data/raw/Other/ظ_99.png', 'text': 'ظ'},
    {'image': 'data/raw/Other/ظ_987.png', 'text': 'ظ'},
    {'image': 'data/raw/Other/ع_99.png', 'text': 'ع'},
    {'image': 'data/raw/Other/ع_990.png', 'text': 'ع'},
    {'image': 'data/raw/Other/غ_99.png', 'text': 'غ'},
    {'image': 'data/raw/Other/غ_984.png', 'text': 'غ'},
    {'image': 'data/raw/Other/ف_993.png', 'text': 'ف'},
    {'image': 'data/raw/Other/ف_994.png', 'text': 'ف'},
    {'image': 'data/raw/Other/ق_992.png', 'text': 'ق'},
    {'image': 'data/raw/Other/ق_993.png', 'text': 'ق'},
    {'image': 'data/raw/Other/ک_0.png', 'text': 'ک'},
    {'image': 'data/raw/Other/ک_1.png', 'text': 'ک'},
    {'image': 'data/raw/Other/گ_0.png', 'text': 'گ'},
    {'image': 'data/raw/Other/گ_1.png', 'text': 'گ'},
    {'image': 'data/raw/Other/ل_983.png', 'text': 'ل'},
    {'image': 'data/raw/Other/ل_984.png', 'text': 'ل'},
    {'image': 'data/raw/Other/م_95.png', 'text': 'م'},
    {'image': 'data/raw/Other/م_96.png', 'text': 'م'},
    {'image': 'data/raw/Other/م_97.png', 'text': 'م'},
    {'image': 'data/raw/Other/م_98.png', 'text': 'م'},
    {'image': 'data/raw/Other/ن_96.png', 'text': 'ن'},
    {'image': 'data/raw/Other/ن_97.png', 'text': 'ن'},
    {'image': 'data/raw/Other/ھ_0.png', 'text': 'ھ'},
    {'image': 'data/raw/Other/ھ_1.png', 'text': 'ھ'},
    {'image': 'data/raw/Other/ہ_96.png', 'text': 'ہ'},
    {'image': 'data/raw/Other/ہ_97.png', 'text': 'ہ'},
    {'image': 'data/raw/Other/و_0.png', 'text': 'و'},
    {'image': 'data/raw/Other/و_1.png', 'text': 'و'},
    {'image': 'data/raw/Other/ے_51.png', 'text': 'ے'},
    {'image': 'data/raw/Other/ے_52.png', 'text': 'ے'},
    {'image': 'data/raw/Other/ی_99.png', 'text': 'ی'},
    {'image': 'data/raw/Other/ی_983.png', 'text': 'ی'},
]

# Combine ALL labels
labels = (synthetic_labels + synthetic_naskh_labels + handwritten_labels +
          newspaper_labels + signboards_labels + books_labels + other_labels)

with open('data/labels.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=['image', 'text'])
    writer.writeheader()
    writer.writerows(labels)

print(f'Labels file created with {len(labels)} entries')
# Out:
# Labels file created with 200 entries

# %% [markdown]
# **Save labels.csv permanently to Google Drive**
#
# Colab's local `data/` folder is temporary — it gets wiped whenever the runtime restarts or disconnects. Saving a backup copy of `labels.csv` to Drive means we never have to regenerate it from scratch.

# %%
import os

os.makedirs('/content/drive/MyDrive/UrduOCR', exist_ok=True)

with open('/content/drive/MyDrive/UrduOCR/labels.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=['image', 'text'])
    writer.writeheader()
    writer.writerows(labels)

print(f'Backup saved to Drive: {len(labels)} entries -> /content/drive/MyDrive/UrduOCR/labels.csv')
# Out:
# Backup saved to Drive: 200 entries -> /content/drive/MyDrive/UrduOCR/labels.csv

# %%
import os
total_files = 0
for folder in os.listdir('data/raw'):
    folder_path = f'data/raw/{folder}'
    if os.path.isdir(folder_path):
        count = len(os.listdir(folder_path))
        total_files += count
        print(f'{folder}: {count} images')

print(f'\nTotal images in data/raw: {total_files}')

import pandas as pd
df = pd.read_csv('data/labels.csv')
print(f'Total entries in labels.csv: {len(df)}')
# Out:
# Handwritten: 0 images
# Sign boards: 0 images
# Newspaper: 0 images
# Synthetic raw images: 41 images
# Books: 0 images
# Other: 0 images
#
# Total images in data/raw: 41
# Total entries in labels.csv: 200

# %%
# --- NEW: backup the actual raw images (not just labels.csv) to Drive ---
import shutil, os

DRIVE_ROOT = '/content/drive/MyDrive/UrduOCR'
os.makedirs(f'{DRIVE_ROOT}/raw', exist_ok=True)

shutil.copytree('data/raw', f'{DRIVE_ROOT}/raw', dirs_exist_ok=True)
print('Raw images backed up to Drive:', DRIVE_ROOT + '/raw')

import glob
print('Total images now on Drive:', len(glob.glob(f'{DRIVE_ROOT}/raw/**/*', recursive=True)))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1205/2579689963.py in <cell line: 0>()
#       5 os.makedirs(f'{DRIVE_ROOT}/raw', exist_ok=True)
#       6
# ----> 7 shutil.copytree('data/raw', f'{DRIVE_ROOT}/raw', dirs_exist_ok=True)
#       8 print('Raw images backed up to Drive:', DRIVE_ROOT + '/raw')
#       9
#
# /usr/lib/python3.12/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     596     """
#     597     sys.audit("shutil.copytree", src, dst)
# --> 598     with os.scandir(src) as itr:
#     599         entries = list(itr)
#     600     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/raw'
